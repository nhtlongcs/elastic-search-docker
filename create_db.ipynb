# %%
from pathlib import Path
import json
from datetime import datetime
import re
data_dir = Path('/home/vbs/vbs23/data/information/metadata/')

# %%
list(data_dir.iterdir())[:3]
# Out:
# [PosixPath('/home/vbs/vbs23/data/information/metadata/Dapang_Jul2022'),
#  PosixPath('/home/vbs/vbs23/data/information/metadata/PhuQuoc1_Jun2022'),
#  PosixPath('/home/vbs/vbs23/data/information/metadata/Molokai_Jul2022')]

# %%
for dirname in data_dir.iterdir():
    dirname_pattern = re.compile(r'(\w+)_(\w+)(\d{4})')
    loc, month, year = dirname_pattern.match(dirname.name).groups()
    print(loc, month, year)
    break
# Out:
# Dapang Jul 2022

# %%
json_example = '/home/vbs/vbs23/data/information/metadata/Ambon_Apr2012/0001.json'
# !cat $json_example
# Out:
# {
#     "camera_model": "Canon PowerShot G12",
#     "captions": [
#         {
#             "ClipCapCaption": [
#                 "a diver swims over a coral reef.",
#                 "coral reef outside the island.",
#                 "coral reef outside the island.",
#                 "coral reef outside the island.",
#                 "coral reef outside the island.",
#                 "a diver swims over a coral reef.",
#                 "coral reef outside the island.",
#                 "coral reef outside the island.",
#                 "a clownfish on a coral reef.",
#                 "a diver swims over a coral reef."
#             ],
#             "id": [
#                 "00001",
#                 "00002",
#                 "00003",
#                 "00004",
#                 "00005",
#                 "00006",
#                 "00007",
#                 "00008",
#                 "00009",
#                 "00010"
#             ]
#         }
#     ],
#     "created_time": "2012:04:04 03:08:10",
#     "duration": "10.47 s",
#     "ext": "mp4",
#     "filename": "0001.mp4",
#     "fps": "23.976",
#     "height": "720",
#     "selected_frames": [
#         {
#             "id": [
#                 "00001",
#                 "00002",
#                 "00003",
#                 "00004",
#                 "00005",
#                 "00006",
#                 "00007",
#                 "00008",
#                 "00009",
#                 "00010"
#             ],
#             "path": [
#                 "information/selected_frames/Ambon_Apr2012/0001_00001.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00002.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00003.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00004.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00005.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00006.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00007.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00008.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00009.jpg",
#                 "information/selected_frames/Ambon_Apr2012/0001_00010.jpg"
#             ]
#         }
#     ],
#     "thumbnails": [
#         {
#             "id": [
#                 "00001",
#                 "00002",
#                 "00003",
#                 "00004",
#                 "00005",
#                 "00006",
#                 "00007",
#                 "00008",
#                 "00009",
#                 "00010"
#             ],
#             "path": [
#                 "information/thumbnails/Ambon_Apr2012/0001_00001.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00002.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00003.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00004.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00005.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00006.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00007.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00008.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00009.jpg",
#                 "information/thumbnails/Ambon_Apr2012/0001_00010.jpg"
#             ]
#         }
#     ],
#     "width": "1280"
# }

# %%
# !cat db_schema.py
# Out:
# from typing import List, Optional
# from pydantic import BaseModel
#
# class SelectedFrames(BaseModel):
#     id: List[str]
#     path: List[str]
#
# class Thumbnails(BaseModel):
#     id: List[str]
#     path: List[str]
#
# class ClipCapCaption(BaseModel):
#     id: List[str]
#     ClipCapCaption: List[str]
#
# class Video(BaseModel):
#     camera_model: str
#     created_time: str
#     duration: str
#     ext: str
#     filename: str
#     fps: str
#     height: str
#     width: str
#     captions: List[ClipCapCaption]
#     selected_frames: List[SelectedFrames]
#     thumbnails: List[Thumbnails]
#
# # {
# #     "camera_model": "Canon PowerShot G12",
# #     "captions": [
# #         {
# #             "ClipCapCaption": [
# #                 "a diver swims over a coral reef.",
# #                 "coral reef outside the island.",
# #                 "coral reef outside the island.",
# #                 "coral reef outside the island.",
# #                 "coral reef outside the island.",
# #                 "a diver swims over a coral reef.",
# #                 "coral reef outside the island.",
# #                 "coral reef outside the island.",
# #                 "a clownfish on a coral reef.",
# #                 "a diver swims over a coral reef."
# #             ],
# #             "id": [
# #                 "00001",
# #                 "00002",
# #                 "00003",
# #                 "00004",
# #                 "00005",
# #                 "00006",
# #                 "00007",
# #                 "00008",
# #                 "00009",
# #                 "00010"
# #             ]
# #         }
# #     ],
# #     "created_time": "2012:04:04 03:08:10",
# #     "duration": "10.47 s",
# #     "ext": "mp4",
# #     "filename": "0001.mp4",
# #     "fps": "23.976",
# #     "height": "720",
# #     "selected_frames": [
# #         {
# #             "id": [
# #                 "00001",
# #                 "00002",
# #                 "00003",
# #                 "00004",
# #                 "00005",
# #                 "00006",
# #                 "00007",
# #                 "00008",
# #                 "00009",
# #                 "00010"
# #             ],
# #             "path": [
# #                 "information/selected_frames/Ambon_Apr2012/0001_00001.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00002.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00003.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00004.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00005.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00006.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00007.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00008.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00009.jpg",
# #                 "information/selected_frames/Ambon_Apr2012/0001_00010.jpg"
# #             ]
# #         }
# #     ],
# #     "thumbnails": [
# #         {
# #             "id": [
# #                 "00001",
# #                 "00002",
# #                 "00003",
# #                 "00004",
# #                 "00005",
# #                 "00006",
# #                 "00007",
# #                 "00008",
# #                 "00009",
# #                 "00010"
# #             ],
# #             "path": [
# #                 "information/thumbnails/Ambon_Apr2012/0001_00001.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00002.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00003.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00004.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00005.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00006.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00007.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00008.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00009.jpg",
# #                 "information/thumbnails/Ambon_Apr2012/0001_00010.jpg"
# #             ]
# #         }
# #     ],
# #     "width": "1280"
# # }

# %%
from db_schema import Video
import pydantic
json_valid = pydantic.parse_file_as(path=json_example, type_=Video)
json_valid
# Out:
# Video(camera_model='Canon PowerShot G12', created_time='2012:04:04 03:08:10', duration='10.47 s', ext='mp4', filename='0001.mp4', fps='23.976', height='720', width='1280', captions=[ClipCapCaption(id=['00001', '00002', '00003', '00004', '00005', '00006', '00007', '00008', '00009', '00010'], ClipCapCaption=['a diver swims over a coral reef.', 'coral reef outside the island.', 'coral reef outside the island.', 'coral reef outside the island.', 'coral reef outside the island.', 'a diver swims over a coral reef.', 'coral reef outside the island.', 'coral reef outside the island.', 'a clownfish on a coral reef.', 'a diver swims over a coral reef.'])], selected_frames=[SelectedFrames(id=['00001', '00002', '00003', '00004', '00005', '00006', '00007', '00008', '00009', '00010'], path=['information/selected_frames/Ambon_Apr2012/0001_00001.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00002.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00003.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00004.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00005.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00006.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00007.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00008.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00009.jpg', 'information/selected_frames/Ambon_Apr2012/0001_00010.jpg'])], thumbnails=[Thumbnails(id=['00001', '00002', '00003', '00004', '00005', '00006', '00007', '00008', '00009', '00010'], path=['information/thumbnails/Ambon_Apr2012/0001_00001.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00002.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00003.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00004.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00005.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00006.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00007.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00008.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00009.jpg', 'information/thumbnails/Ambon_Apr2012/0001_00010.jpg'])])

# %%
def time2part_of_day(hour: int):
    # part_of_day = [
    #     'early morning',
    #     'morning',
    #     'late morning',
    #     'early afternoon',
    #     'afternoon',
    #     'early evening',
    #     'evening',
    #     'late afternoon',
    #     'night',
    # ]
    
    if (hour >= 5) and (hour < 9):
        return 'early morning'
    elif (hour >= 9) and (hour < 11):
        return 'morning'
    elif (hour >= 11) and (hour < 12):
        return 'late morning'
    elif (hour >= 12) and (hour < 15):
        return 'early afternoon'
    elif (hour >= 15) and (hour < 16):
        return 'afternoon'
    elif (hour >= 16) and (hour < 17):
        return 'late afternoon'
    elif (hour >= 17) and (hour < 19):
        return 'early evening'
    elif (hour >= 19) and (hour < 21):
        return 'early evening'
    elif (hour >= 21) and (hour < 23):
        return 'late afternoon'
    else:
        return 'night'
        
def time2day_of_week(day: int):
    day_of_week = [
        'Monday',
        'Tuesday',
        'Wednesday',
        'Thursday',
        'Friday',
        'Saturday',
        'Sunday',
    ]
    return day_of_week[day]
def time2month(month: int):
    month_of_year = [
        'January',
        'February',
        'March',
        'April',
        'May',
        'June',
        'July',
        'August',
        'September',
        'October',
        'November',
        'December',
    ]
    assert month <= 12, f'Invalid month: {month}'
    assert month > 0, f'Invalid month: {month}'
    return month_of_year[month-1]

# %%
result = {}

for dirname in data_dir.iterdir():
    dirname_pattern = re.compile(r'(\w+)_(\w+)(\d{4})')
    loc, month, year = dirname_pattern.match(dirname.name).groups()
    # print(loc, month, year)
    for json_file in dirname.iterdir():
        json_valid = pydantic.parse_file_as(path=json_file, type_=Video)
        
        shot_name = int(json_file.stem)

        cap_ids = json_valid.captions[0].id
        thum_ids = json_valid.thumbnails[0].id
        fram_ids = json_valid.selected_frames[0].id
        
        assert cap_ids == thum_ids == fram_ids, 'ids not equal'

        ids = list(map(int, cap_ids))

        for _id in ids: 
            _time = datetime.strptime(json_valid.created_time, '%Y:%m:%d %H:%M:%S')
            item = {
                'id': _id,
                'location': loc,
                # 'month': month,
                # 'year': year,
                'camera_model': json_valid.camera_model,
                'thumbnails': json_valid.thumbnails[0].path[_id-1],
                'selected_frames': json_valid.selected_frames[0].path[_id-1],
                'created_time': json_valid.created_time,
                'date': _time.date().strftime('%Y-%m-%d'),
                'month': time2month(_time.month),
                'year': _time.year,
                'day_of_week': time2day_of_week(_time.weekday()),
                'part_of_day': time2part_of_day(_time.hour),
                'local_time': _time.time().strftime('%H:%M'),
                'captions': json_valid.captions[0].ClipCapCaption[_id-1],
                'width': json_valid.width,
                'height': json_valid.height,
                'ext': json_valid.ext,
                'fps': json_valid.fps,
            }
            result[f'{dirname.name}_{shot_name}_{_id}'] = item

# %%
result
# Out:
# {'Dapang_Jul2022_5_1': {'id': 1,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_00001.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0005_00001.jpg',
#   'created_time': '2022:08:27 07:48:37',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:48',
#   'captions': 'underwater view of a coral reef.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_5_2': {'id': 2,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_00002.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0005_00002.jpg',
#   'created_time': '2022:08:27 07:48:37',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:48',
#   'captions': 'the reef is a bit smaller than the ones we saw.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_5_3': {'id': 3,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_00003.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0005_00003.jpg',
#   'created_time': '2022:08:27 07:48:37',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:48',
#   'captions': 'the reef is a bit more shallow than the beach.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_5_4': {'id': 4,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_00004.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0005_00004.jpg',
#   'created_time': '2022:08:27 07:48:37',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:48',
#   'captions': 'a small group of fish swim.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_5_5': {'id': 5,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_00005.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0005_00005.jpg',
#   'created_time': '2022:08:27 07:48:37',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:48',
#   'captions': 'a small group of fish swim around a coral reef.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_5_6': {'id': 6,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_00006.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0005_00006.jpg',
#   'created_time': '2022:08:27 07:48:37',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:48',
#   'captions': 'a large group of fish swim.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_5_7': {'id': 7,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_00007.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0005_00007.jpg',
#   'created_time': '2022:08:27 07:48:37',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:48',
#   'captions': 'a small group of fish swim around a coral reef.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_5_8': {'id': 8,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_00008.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0005_00008.jpg',
#   'created_time': '2022:08:27 07:48:37',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:48',
#   'captions': 'a wide shot of a coral reef.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_5_9': {'id': 9,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0005_
',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_3_5': {'id': 5,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0003_00005.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0003_00005.jpg',
#   'created_time': '2022:08:27 07:55:08',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:55',
#   'captions': 'a pair of dolphins swimming in the water.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_3_6': {'id': 6,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0003_00006.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0003_00006.jpg',
#   'created_time': '2022:08:27 07:55:08',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:55',
#   'captions': 'a view of the water.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_3_7': {'id': 7,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0003_00007.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0003_00007.jpg',
#   'created_time': '2022:08:27 07:55:08',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:55',
#   'captions': 'the water was so clear that the fish were able to swim underwater.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_3_8': {'id': 8,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0003_00008.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0003_00008.jpg',
#   'created_time': '2022:08:27 07:55:08',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:55',
#   'captions': 'a man swims in the sea.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_3_9': {'id': 9,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0003_00009.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0003_00009.jpg',
#   'created_time': '2022:08:27 07:55:08',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:55',
#   'captions': 'a view of the water surface.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_3_10': {'id': 10,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0003_00010.jpg',
#   'selected_frames': 'information/selected_frames/Dapang_Jul2022/0003_00010.jpg',
#   'created_time': '2022:08:27 07:55:08',
#   'date': '2022-08-27',
#   'month': 'August',
#   'year': 2022,
#   'day_of_week': 'Saturday',
#   'part_of_day': 'early morning',
#   'local_time': '07:55',
#   'captions': 'a man swimming in the sea.',
#   'width': '1920',
#   'height': '1080',
#   'ext': 'mp4',
#   'fps': '30'},
#  'Dapang_Jul2022_3_11': {'id': 11,
#   'location': 'Dapang',
#   'camera_model': 'DJI Osmo 3',
#   'thumbnails': 'information/thumbnails/Dapang_Jul2022/0003_00011.jpg',
# ...
#   'local_time': '12:47',
#   'captions': 'a reef of soft corals.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_71_15': {'id': 15,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0071_00015.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0071_00015.jpg',
#   'created_time': '2022:06:10 12:47:51',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:47',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_71_16': {'id': 16,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0071_00016.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0071_00016.jpg',
#   'created_time': '2022:06:10 12:47:51',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:47',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_71_17': {'id': 17,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0071_00017.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0071_00017.jpg',
#   'created_time': '2022:06:10 12:47:51',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:47',
#   'captions': 'fish swimming around the reef.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_71_18': {'id': 18,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0071_00018.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0071_00018.jpg',
#   'created_time': '2022:06:10 12:47:51',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:47',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_71_19': {'id': 19,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0071_00019.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0071_00019.jpg',
#   'created_time': '2022:06:10 12:47:51',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:47',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_71_20': {'id': 20,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0071_00020.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0071_00020.jpg',
#   'created_time': '2022:06:10 12:47:51',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:47',
#   'captions': 'fish swimming around the reef.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_1': {'id': 1,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00001.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00001.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'a coral reef grows in the waters.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_2': {'id': 2,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00002.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00002.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'fish in the coral reef.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_3': {'id': 3,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00003.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00003.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'a coral reef in the sea.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_4': {'id': 4,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00004.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00004.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_5': {'id': 5,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00005.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00005.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_6': {'id': 6,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00006.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00006.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'fish swimming around in the coral reef.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_7': {'id': 7,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00007.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00007.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'fish in the coral reef.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_8': {'id': 8,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00008.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00008.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_9': {'id': 9,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00009.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00009.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_10': {'id': 10,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00010.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00010.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_11': {'id': 11,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00011.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00011.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_12': {'id': 12,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00012.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00012.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_13': {'id': 13,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00013.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00013.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_14': {'id': 14,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00014.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00014.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_15': {'id': 15,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00015.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00015.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_16': {'id': 16,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00016.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00016.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_17': {'id': 17,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00017.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00017.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_18': {'id': 18,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00018.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00018.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_19': {'id': 19,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00019.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00019.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_20': {'id': 20,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00020.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00020.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_21': {'id': 21,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00021.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00021.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  'PhuQuoc1_Jun2022_51_22': {'id': 22,
#   'location': 'PhuQuoc1',
#   'camera_model': 'HERO10 Black',
#   'thumbnails': 'information/thumbnails/PhuQuoc1_Jun2022/0051_00022.jpg',
#   'selected_frames': 'information/selected_frames/PhuQuoc1_Jun2022/0051_00022.jpg',
#   'created_time': '2022:06:10 12:17:48',
#   'date': '2022-06-10',
#   'month': 'June',
#   'year': 2022,
#   'day_of_week': 'Friday',
#   'part_of_day': 'early afternoon',
#   'local_time': '12:17',
#   'captions': 'coral reef outside the island.',
#   'width': '3840',
#   'height': '2160',
#   'ext': 'mp4',
#   'fps': '29.97'},
#  ...}

# %%
len(result)
# Out:
# 43797

# %%
# convert to dataframe
import pandas as pd
df = pd.DataFrame.from_dict(result, orient='index')
df['index'] = df.index
df.head()
# Out:
#                     id location camera_model  \
# Dapang_Jul2022_5_1   1   Dapang   DJI Osmo 3
# Dapang_Jul2022_5_2   2   Dapang   DJI Osmo 3
# Dapang_Jul2022_5_3   3   Dapang   DJI Osmo 3
# Dapang_Jul2022_5_4   4   Dapang   DJI Osmo 3
# Dapang_Jul2022_5_5   5   Dapang   DJI Osmo 3
#
#                                                            thumbnails  \
# Dapang_Jul2022_5_1  information/thumbnails/Dapang_Jul2022/0005_000...
# Dapang_Jul2022_5_2  information/thumbnails/Dapang_Jul2022/0005_000...
# Dapang_Jul2022_5_3  information/thumbnails/Dapang_Jul2022/0005_000...
# Dapang_Jul2022_5_4  information/thumbnails/Dapang_Jul2022/0005_000...
# Dapang_Jul2022_5_5  information/thumbnails/Dapang_Jul2022/0005_000...
#
#                                                       selected_frames  \
# Dapang_Jul2022_5_1  information/selected_frames/Dapang_Jul2022/000...
# Dapang_Jul2022_5_2  information/selected_frames/Dapang_Jul2022/000...
# Dapang_Jul2022_5_3  information/selected_frames/Dapang_Jul2022/000...
# Dapang_Jul2022_5_4  information/selected_frames/Dapang_Jul2022/000...
# Dapang_Jul2022_5_5  information/selected_frames/Dapang_Jul2022/000...
#
#                            created_time        date   month  year day_of_week  \
# Dapang_Jul2022_5_1  2022:08:27 07:48:37  2022-08-27  August  2022    Saturday
# Dapang_Jul2022_5_2  2022:08:27 07:48:37  2022-08-27  August  2022    Saturday
# Dapang_Jul2022_5_3  2022:08:27 07:48:37  2022-08-27  August  2022    Saturday
# Dapang_Jul2022_5_4  2022:08:27 07:48:37  2022-08-27  August  2022    Saturday
# Dapang_Jul2022_5_5  2022:08:27 07:48:37  2022-08-27  August  2022    Saturday
#
#                       part_of_day local_time  \
# Dapang_Jul2022_5_1  early morning      07:48
# Dapang_Jul2022_5_2  early morning      07:48
# Dapang_Jul2022_5_3  early morning      07:48
# Dapang_Jul2022_5_4  early morning      07:48
# Dapang_Jul2022_5_5  early morning      07:48
#
#                                                            captions width  \
# Dapang_Jul2022_5_1                 underwater view of a coral reef.  1920
# Dapang_Jul2022_5_2  the reef is a bit smaller than the ones we saw.  1920
# Dapang_Jul2022_5_3   the reef is a bit more shallow than the beach.  1920
# Dapang_Jul2022_5_4                      a small group of fish swim.  1920
# Dapang_Jul2022_5_5  a small group of fish swim around a coral reef.  1920
#
#                    height  ext fps               index
# Dapang_Jul2022_5_1   1080  mp4  30  Dapang_Jul2022_5_1
# Dapang_Jul2022_5_2   1080  mp4  30  Dapang_Jul2022_5_2
# Dapang_Jul2022_5_3   1080  mp4  30  Dapang_Jul2022_5_3
# Dapang_Jul2022_5_4   1080  mp4  30  Dapang_Jul2022_5_4
# Dapang_Jul2022_5_5   1080  mp4  30  Dapang_Jul2022_5_5

# %%
df.to_csv('vbs23_meta.csv', index=True)
