# %%
from processor import Processor

class _C: 
    ES_INDEX = 'vbs23_db'
    ES_HOST = 'http://0.0.0.0'
    ES_PORT = 9200
    ES_RETURN_SIZE = 2048

config = _C()

es_processor = Processor(config)
# Out:
# Connected to Elasticsearch node

# %%
# import logging 
# logging.basicConfig(level=logging.DEBUG)
# es_processor.search('underwater ; Oahu; monday afternoon in 2018')['hits']['hits']
es_processor.search(' ;;Tuesday 2022')['hits']['hits']
# Out:
# parsing time
# Filtered tokens:  ['tuesday', '2022', '2022-WXX-2', '2022']
# ('tuesday', 'day_of_week')
# Function analyse elapsed time: 0:00:00.013501
# Function run elapsed time: 0:00:00.000003
# {'query': {'bool': {'filter': [{'term': {'day_of_week': 'tuesday'}}]}}}
# Function search elapsed time: 0:00:00.050735
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Registering annotator sutime with class edu.stanford.nlp.time.TimeAnnotator
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator tokenize
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ssplit
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator pos
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator lemma
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator ner
# [main] INFO edu.stanford.nlp.pipeline.StanfordCoreNLP - Adding annotator sutime
# [{'_index': 'vbs23_db',
# ...
